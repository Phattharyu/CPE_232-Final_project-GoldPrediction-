# %% [markdown]
# # **Import Library & Data from yahoo finance**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandas_datareader.data import DataReader
import yfinance as yf
import pandas_datareader as pdr

from datetime import datetime

# !gdown 14iSHWNraKglyrcLFQe5-GprkjkO6xaCK

df = pd.read_csv('Merged_Gold_dataset.csv')
df
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14iSHWNraKglyrcLFQe5-GprkjkO6xaCK
# To: /content/Merged_Gold_dataset.csv
# 100% 1.02M/1.02M [00:00<00:00, 14.8MB/s]
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2005-03-28   425.899994   425.899994   425.899994
# 1              1  2005-03-29   426.000000   426.000000   426.000000
# 2              2  2005-03-31   428.700012   428.700012   428.700012
# 3              3  2005-04-01   425.899994   428.500000   424.500000
# 4              4  2005-04-04   423.899994   426.299988   422.700012
# ...          ...         ...          ...          ...          ...
# 5003        5003  2025-02-21  2937.600098  2940.000000  2917.300049
# 5004        5004  2025-02-24  2947.899902  2957.899902  2933.100098
# 5005        5005  2025-02-25  2904.500000  2943.199951  2890.000000
# 5006        5006  2025-02-26  2916.800049  2917.000000  2913.000000
# 5007        5007  2025-02-27  2883.199951  2922.800049  2870.399902
#
#              Open  Volume        RSI        SMA10        SMA20  CPIAUCSL  \
# 0      425.899994       0  33.386323   434.190002   435.730000   193.100
# 1      426.000000       0  33.629056   432.680002   435.205000   193.100
# 2      428.700012    3051  39.987248   431.460004   434.995001   193.100
# 3      428.299988     552  36.122564   429.680002   434.650002   193.700
# 4      426.000000     486  33.622901   428.200000   434.350002   193.700
# ...           ...     ...        ...          ...          ...       ...
# 5003  2938.800049     570  68.447600  2914.120020  2862.110022   319.775
# 5004  2933.100098     415  69.639013  2922.180005  2870.640015   319.775
# 5005  2938.699951    1854  59.452120  2921.200000  2878.990015   319.775
# 5006  2913.500000    2050  61.185088  2921.630005  2886.490015   319.775
# 5007  2918.500000    3215  54.351452  2919.050000  2892.195007   319.775
#
#       CIVPART        GDP  GEPUCURRENT   PPIACO  UNRATE        CLI  \
# 0        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 1        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 2        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 3        66.1  12922.656    68.682759  155.000     5.2  100.29310
# 4        66.1  12922.656    68.682759  155.000     5.2  100.29310
# ...       ...        ...          ...      ...     ...        ...
# 5003     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5004     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5005     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5006     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5007     62.4  29723.864   429.830565  259.805     4.1   99.85411
#
#       GDP_Reference
# 0          100.4980
# 1          100.4980
# 2          100.4980
# 3          100.5254
# 4          100.5254
# ...             ...
# 5003       100.4912
# 5004       100.4912
# 5005       100.4912
# 5006       100.4912
# 5007       100.4912
#
# [5008 rows x 18 columns]

# %%
df
# Out:
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2005-03-28   425.899994   425.899994   425.899994
# 1              1  2005-03-29   426.000000   426.000000   426.000000
# 2              2  2005-03-31   428.700012   428.700012   428.700012
# 3              3  2005-04-01   425.899994   428.500000   424.500000
# 4              4  2005-04-04   423.899994   426.299988   422.700012
# ...          ...         ...          ...          ...          ...
# 5003        5003  2025-02-21  2937.600098  2940.000000  2917.300049
# 5004        5004  2025-02-24  2947.899902  2957.899902  2933.100098
# 5005        5005  2025-02-25  2904.500000  2943.199951  2890.000000
# 5006        5006  2025-02-26  2916.800049  2917.000000  2913.000000
# 5007        5007  2025-02-27  2883.199951  2922.800049  2870.399902
#
#              Open  Volume        RSI        SMA10        SMA20  CPIAUCSL  \
# 0      425.899994       0  33.386323   434.190002   435.730000   193.100
# 1      426.000000       0  33.629056   432.680002   435.205000   193.100
# 2      428.700012    3051  39.987248   431.460004   434.995001   193.100
# 3      428.299988     552  36.122564   429.680002   434.650002   193.700
# 4      426.000000     486  33.622901   428.200000   434.350002   193.700
# ...           ...     ...        ...          ...          ...       ...
# 5003  2938.800049     570  68.447600  2914.120020  2862.110022   319.775
# 5004  2933.100098     415  69.639013  2922.180005  2870.640015   319.775
# 5005  2938.699951    1854  59.452120  2921.200000  2878.990015   319.775
# 5006  2913.500000    2050  61.185088  2921.630005  2886.490015   319.775
# 5007  2918.500000    3215  54.351452  2919.050000  2892.195007   319.775
#
#       CIVPART        GDP  GEPUCURRENT   PPIACO  UNRATE        CLI  \
# 0        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 1        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 2        65.9  12767.286    54.055710  153.700     5.2  100.34460
# 3        66.1  12922.656    68.682759  155.000     5.2  100.29310
# 4        66.1  12922.656    68.682759  155.000     5.2  100.29310
# ...       ...        ...          ...      ...     ...        ...
# 5003     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5004     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5005     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5006     62.4  29723.864   429.830565  259.805     4.1   99.85411
# 5007     62.4  29723.864   429.830565  259.805     4.1   99.85411
#
#       GDP_Reference
# 0          100.4980
# 1          100.4980
# 2          100.4980
# 3          100.5254
# 4          100.5254
# ...             ...
# 5003       100.4912
# 5004       100.4912
# 5005       100.4912
# 5006       100.4912
# 5007       100.4912
#
# [5008 rows x 18 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#             Date        Close         High          Low         Open  Volume  \
# 0     2005-03-28   425.899994   425.899994   425.899994   425.899994       0
# 1     2005-03-29   426.000000   426.000000   426.000000   426.000000       0
# 2     2005-03-31   428.700012   428.700012   428.700012   428.700012    3051
# 3     2005-04-01   425.899994   428.500000   424.500000   428.299988     552
# 4     2005-04-04   423.899994   426.299988   422.700012   426.000000     486
# ...          ...          ...          ...          ...          ...     ...
# 5003  2025-02-21  2937.600098  2940.000000  2917.300049  2938.800049     570
# 5004  2025-02-24  2947.899902  2957.899902  2933.100098  2933.100098     415
# 5005  2025-02-25  2904.500000  2943.199951  2890.000000  2938.699951    1854
# 5006  2025-02-26  2916.800049  2917.000000  2913.000000  2913.500000    2050
# 5007  2025-02-27  2883.199951  2922.800049  2870.399902  2918.500000    3215
#
#             RSI        SMA10        SMA20  CPIAUCSL  CIVPART        GDP  \
# 0     33.386323   434.190002   435.730000   193.100     65.9  12767.286
# 1     33.629056   432.680002   435.205000   193.100     65.9  12767.286
# 2     39.987248   431.460004   434.995001   193.100     65.9  12767.286
# 3     36.122564   429.680002   434.650002   193.700     66.1  12922.656
# 4     33.622901   428.200000   434.350002   193.700     66.1  12922.656
# ...         ...          ...          ...       ...      ...        ...
# 5003  68.447600  2914.120020  2862.110022   319.775     62.4  29723.864
# 5004  69.639013  2922.180005  2870.640015   319.775     62.4  29723.864
# 5005  59.452120  2921.200000  2878.990015   319.775     62.4  29723.864
# 5006  61.185088  2921.630005  2886.490015   319.775     62.4  29723.864
# 5007  54.351452  2919.050000  2892.195007   319.775     62.4  29723.864
#
#       GEPUCURRENT   PPIACO  UNRATE        CLI  GDP_Reference
# 0       54.055710  153.700     5.2  100.34460       100.4980
# 1       54.055710  153.700     5.2  100.34460       100.4980
# 2       54.055710  153.700     5.2  100.34460       100.4980
# 3       68.682759  155.000     5.2  100.29310       100.5254
# 4       68.682759  155.000     5.2  100.29310       100.5254
# ...           ...      ...     ...        ...            ...
# 5003   429.830565  259.805     4.1   99.85411       100.4912
# 5004   429.830565  259.805     4.1   99.85411       100.4912
# 5005   429.830565  259.805     4.1   99.85411       100.4912
# 5006   429.830565  259.805     4.1   99.85411       100.4912
# 5007   429.830565  259.805     4.1   99.85411       100.4912
#
# [5008 rows x 17 columns]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [2, 1]}, figsize=(10, 6))


# Plot close price
ax1.plot(df['Close'], label='Close Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Close Price and RSI')
ax1.legend(loc='upper left')

# Plot RSI
ax2.plot(df['RSI'], label='RSI', color='purple')
ax2.axhline(70, color='red', linestyle='--', label='Overbought (70)')
ax2.axhline(30, color='green', linestyle='--', label='Oversold (30)')
ax2.set_ylabel('RSI')
ax2.set_xlabel('Time')
ax2.legend(loc='upper left')
ax2.set_ylim(0, 100)

# Adjust layout and display plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,4), dpi =500)
sns.heatmap(df.corr(numeric_only=True)[['Close']].sort_values(by='Close', ascending=False),
            annot=True, fmt=".4f", linewidth=.5, annot_kws={"size": 8})
plt.show()

# %%
sns.pairplot(df,x_vars=['Close'])

# %% [markdown]
# After Visualizing the correlation and relationship between close and other features, we assume that all of Price features have a near 1 relationship with Close price except Volume. Moreover, **SMA10 and SMA20** have a direct variation except RSI since it's called a momentum indicator. For relationship between Close Price and Economy indexes, after visualizing in pairplot and correlation table, PPI, GDP, and CPI have high correlation and a direct variation with Close price. However, CIV has an inverse variation with Close Price.

# %% [markdown]
# # **MinMaxScaler**

# %% [markdown]
# # **Data Processing**

# %%
train_size = round(len(df)*0.75)
val_size = round(len(df)*0.9) - round(len(df)*0.75)
test_size = len(df) - train_size - val_size
print('Train:',train_size,'Valid:',val_size,'Test:',test_size)
# Out:
# Train: 3756 Valid: 751 Test: 501

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df.Close.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
train_data = df.Close[:train_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

val_data = df.Close[train_size:train_size+val_size]
val_data = scaler.transform(val_data.values.reshape(-1,1))

test_data = df.Close[train_size+val_size:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
scaler_sma10 = MinMaxScaler()
scaler_sma10.fit(df.Close.values.reshape(-1,1))
train_data_sma10 = df['SMA10'][:train_size]
train_data_sma10 = scaler_sma10.transform(train_data_sma10.values.reshape(-1,1))

val_data_sma10 = df['SMA10'][train_size:train_size+val_size]
val_data_sma10 = scaler_sma10.transform(val_data_sma10.values.reshape(-1,1))

test_data_sma10 = df['SMA10'][train_size+val_size:]
test_data_sma10 = scaler_sma10.transform(test_data_sma10.values.reshape(-1,1))

# %%
scaler_sma20 = MinMaxScaler()
scaler_sma20.fit(df.SMA20.values.reshape(-1,1))
train_data_sma20 = df['SMA20'][:train_size]
train_data_sma20 = scaler_sma20.transform(train_data_sma20.values.reshape(-1,1))

val_data_sma20 = df['SMA10'][train_size:train_size+val_size]
val_data_sma20 = scaler_sma20.transform(val_data_sma20.values.reshape(-1,1))

test_data_sma20 = df['SMA20'][train_size+val_size:]
test_data_sma20 = scaler_sma20.transform(test_data_sma20.values.reshape(-1,1))

# %%
train_data_rsi = df['RSI'][:train_size]
val_data_rsi = df['RSI'][train_size:train_size+val_size]
test_data_rsi = df['RSI'][train_size+val_size:]

# %%
train_data_rsi = df['RSI'][:train_size]
test_data_rsi = df['RSI'][train_size:]

# %% [markdown]
# # **Price + Indicators**

# %%
window=5
x_train=[]
y_train = []
for i in range(train_size-window) :
  temp = train_data[i:i+window]
  temp = np.append(temp, train_data_sma10[i:i+window])
  x_train.append(temp)
  y_train.append(train_data[i+window])

# %%
train_size-window
# Out:
# 3751

# %%
x_val=[]
y_val = []
for i in range(window) :
  temp = train_data[i+train_size-window-window:i+train_size-window]
  temp = np.append(temp, train_data_sma10[i+train_size-window-window:i+train_size-window])
  x_val.append(temp)
  y_val.append(train_data[i+train_size-window])
for i in range(val_size-window) :
  temp = val_data[i:i+window]
  temp = np.append(temp, val_data_sma10[i:i+window])
  x_val.append(temp)
  y_val.append(val_data[i+window])

# %%
x_test=[]
y_test = []
for i in range(window) :
  temp = val_data[i-window-window+len(x_val):i+len(x_val)-window]
  temp = np.append(temp, val_data_sma10[i+len(x_val)-window-window:i+len(x_val)-window])
  x_test.append(temp)
  y_test.append(val_data[i+len(x_val)-window-window])
for i in range(test_size-window) :
  temp = test_data[i:i+window]
  temp = np.append(temp, test_data_sma10[i:i+window])
  x_test.append(temp)
  y_test.append(test_data[i+window])

# %%
x_train = np.array(x_train)
x_val = np.array(x_val)
x_test  = np.array(x_test)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test  = np.array(y_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test  = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_val = np.reshape(y_val, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((3751, 10, 1), (3751, 1), (751, 10, 1), (751, 1), (501, 10, 1), (501, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(LSTM(units = 128, return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 64, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=1,activation='linear'))

'''
model = Sequential()
model.add(InputLayer((x_train.shape[1],1)))
model.add(LSTM(64))
model.add(Dense(8,'relu'))
model.add(Dense(1,'linear'))
'''
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_32 (LSTM)                  │ (None, 10, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_33 (LSTM)                  │ (None, 10, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_34 (LSTM)                  │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 128)            │         6,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,625 (568.85 KB)
#  Trainable params: 145,625 (568.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model/lstm.keras',save_best_only = True,monitor='val_root_mean_squared_error',mode='min')
model.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate = 0.00001),metrics = [RootMeanSquaredError()])

# %%
# %%time
model.fit(x_train,y_train,validation_data=(x_val,y_val), epochs= 50,callbacks=[cp1])
# Out:
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - loss: 0.0994 - root_mean_squared_error: 0.3152 - val_loss: 0.2572 - val_root_mean_squared_error: 0.5071
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0806 - root_mean_squared_error: 0.2839 - val_loss: 0.1935 - val_root_mean_squared_error: 0.4399
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0527 - root_mean_squared_error: 0.2295 - val_loss: 0.1044 - val_root_mean_squared_error: 0.3232
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 0.0241 - root_mean_squared_error: 0.1546 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0765
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0579
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0025 - root_mean_squared_error: 0.0499 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 0.0022 - root_mean_squared_error: 0.0474 - val_loss: 7.1063e-04 - val_root_mean_squared_error: 0.0267
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0020 - root_mean_squared_error: 0.0443 - val_loss: 4.2554e-04 - val_root_mean_squared_error: 0.0206
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 2.5828e-04 - val_root_mean_squared_error: 0.0161
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 1.7683e-04 - val_root_mean_squared_error: 0.0133
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 1.9061e-04 - val_root_mean_squared_error: 0.0138
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 1.8852e-04 - val_root_mean_squared_error: 0.0137
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0013 - root_mean_squared_error: 0.0363 - val_loss: 2.0371e-04 - val_root_mean_squared_error: 0.0143
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 2.3412e-04 - val_root_mean_squared_error: 0.0153
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 2.7190e-04 - val_root_mean_squared_error: 0.0165
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 2.3698e-04 - val_root_mean_squared_error: 0.0154
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 2.9664e-04 - val_root_mean_squared_error: 0.0172
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 2.9920e-04 - val_root_mean_squared_error: 0.0173
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 2.6384e-04 - val_root_mean_squared_error: 0.0162
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0010 - root_mean_squared_error: 0.0320 - val_loss: 2.0930e-04 - val_root_mean_squared_error: 0.0145
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 9.6465e-04 - root_mean_squared_error: 0.0311 - val_loss: 2.3872e-04 - val_root_mean_squared_error: 0.0155
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.4597e-04 - root_mean_squared_error: 0.0307 - val_loss: 1.8851e-04 - val_root_mean_squared_error: 0.0137
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 9.2579e-04 - root_mean_squared_error: 0.0304 - val_loss: 2.0851e-04 - val_root_mean_squared_error: 0.0144
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 9.5450e-04 - root_mean_squared_error: 0.0309 - val_loss: 1.8441e-04 - val_root_mean_squared_error: 0.0136
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 9.5476e-04 - root_mean_squared_error: 0.0309 - val_loss: 2.1177e-04 - val_root_mean_squared_error: 0.0146
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.8614e-04 - root_mean_squared_error: 0.0298 - val_loss: 1.8163e-04 - val_root_mean_squared_error: 0.0135
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 8.4573e-04 - root_mean_squared_error: 0.0291 - val_loss: 1.7995e-04 - val_root_mean_squared_error: 0.0134
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 9.2834e-04 - root_mean_squared_error: 0.0305 - val_loss: 1.8022e-04 - val_root_mean_squared_error: 0.0134
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8.4900e-04 - root_mean_squared_error: 0.0291 - val_loss: 1.9170e-04 - val_root_mean_squared_error: 0.0138
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 8.5849e-04 - root_mean_squared_error: 0.0293 - val_loss: 1.9047e-04 - val_root_mean_squared_error: 0.0138
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.3770e-04 - root_mean_squared_error: 0.0289 - val_loss: 3.1091e-04 - val_root_mean_squared_error: 0.0176
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 7.5172e-04 - root_mean_squared_error: 0.0274 - val_loss: 2.5388e-04 - val_root_mean_squared_error: 0.0159
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 8.0787e-04 - root_mean_squared_error: 0.0284 - val_loss: 3.7098e-04 - val_root_mean_squared_error: 0.0193
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 7.1489e-04 - root_mean_squared_error: 0.0267 - val_loss: 3.2110e-04 - val_root_mean_squared_error: 0.0179
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 7.7313e-04 - root_mean_squared_error: 0.0278 - val_loss: 3.1488e-04 - val_root_mean_squared_error: 0.0177
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 7.1567e-04 - root_mean_squared_error: 0.0267 - val_loss: 3.0344e-04 - val_root_mean_squared_error: 0.0174
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 6.8686e-04 - root_mean_squared_error: 0.0262 - val_loss: 3.3402e-04 - val_root_mean_squared_error: 0.0183
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 6.9552e-04 - root_mean_squared_error: 0.0263 - val_loss: 4.0102e-04 - val_root_mean_squared_error: 0.0200
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 6.8235e-04 - root_mean_squared_error: 0.0261 - val_loss: 4.7596e-04 - val_root_mean_squared_error: 0.0218
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 6.7024e-04 - root_mean_squared_error: 0.0259 - val_loss: 5.4674e-04 - val_root_mean_squared_error: 0.0234
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 6.6224e-04 - root_mean_squared_error: 0.0257 - val_loss: 7.3113e-04 - val_root_mean_squared_error: 0.0270
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 6.1670e-04 - root_mean_squared_error: 0.0248 - val_loss: 6.4631e-04 - val_root_mean_squared_error: 0.0254
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 6.3091e-04 - root_mean_squared_error: 0.0251 - val_loss: 6.1369e-04 - val_root_mean_squared_error: 0.0248
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 6.3215e-04 - root_mean_squared_error: 0.0251 - val_loss: 9.7109e-04 - val_root_mean_squared_error: 0.0312
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 5.9972e-04 - root_mean_squared_error: 0.0245 - val_loss: 9.1216e-04 - val_root_mean_squared_error: 0.0302
# CPU times: user 4min 24s, sys: 9.21 s, total: 4min 34s
# Wall time: 3min 46s

# %%
from tensorflow.keras.models import load_model
model = load_model('model/lstm.keras')
# Evaluate the model
result = model.evaluate(x_val, y_val)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5736e-04 - root_mean_squared_error: 0.0157

# %%
# Make predictions
# %%time
y_pred = model.predict(x_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# CPU times: user 1.11 s, sys: 54 ms, total: 1.16 s
# Wall time: 1.33 s

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE
print("Test Loss:", result[0])
print("Test RMSE:", result[1])
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0001768276997609064
# Test RMSE: 0.01329765748232603
# Test MAPE: 0.026107102527988934
# Test Accuracy: 0.973892897472011

# %%
y_val_pred = model.predict(x_val)
y_val_true = scaler.inverse_transform(y_val)
y_val_pred = scaler.inverse_transform(y_val_pred)
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
plt.figure(figsize=(18, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'green'
plt.rc('axes',edgecolor='white')
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df.index[train_size:train_size+val_size], y_val_true, color='blue', lw=2) # Valid True
plt.plot(df.index[train_size:train_size+val_size], y_val_pred, color='red', lw=2) # Valid Pred
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_true, color='yellow', lw=2) # Test True
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_pred, color='orange', lw=2)# Test Pred
plt.title('Model Performance on Gold Price Prediction Using LSTM', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Valid Data', 'Predicted Valid Data','Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # **Price Only**

# %%
train_data = df.Close[:train_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

val_data = df.Close[train_size:train_size+val_size]
val_data = scaler.transform(val_data.values.reshape(-1,1))

test_data = df.Close[train_size+val_size:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
train_data_o = df.Open[:train_size]
train_data_o = scaler.transform(train_data_o.values.reshape(-1,1))

val_data_o = df.Open[train_size:train_size+val_size]
val_data_o = scaler.transform(val_data_o.values.reshape(-1,1))

test_data_o = df.Open[train_size+val_size:]
test_data_o = scaler.transform(test_data_o.values.reshape(-1,1))

# %%
window=10
x_train=[]
y_train = []
for i in range(train_size-window) :
  temp = train_data[i:i+window]
  temp = np.append(temp, train_data_o[i:i+window])
  x_train.append(temp)
  y_train.append(train_data[i+window])

# %%
x_val=[]
y_val = []
for i in range(window) :
  temp = train_data[i+train_size-(2*window):i+train_size-window]
  temp = np.append(temp, train_data_o[i+train_size-window-window:i+train_size-window])
  x_val.append(temp)
  y_val.append(train_data[i+train_size-window])
for i in range(val_size-window) :
  temp = val_data[i:i+window]
  temp = np.append(temp, val_data_o[i:i+window])
  x_val.append(temp)
  y_val.append(val_data[i+window])

# %%
x_test=[]
y_test = []
for i in range(window) :
  temp = val_data[i-window-window+len(x_val):i+len(x_val)-window]
  temp = np.append(temp, val_data_o[i+len(x_val)-window-window:i+len(x_val)-window])
  x_test.append(temp)
  y_test.append(val_data[i+len(x_val)-window-window])
for i in range(test_size-window) :
  temp = test_data[i:i+window]
  temp = np.append(temp, test_data_o[i:i+window])
  x_test.append(temp)
  y_test.append(test_data[i+window])

# %%
x_train = np.array(x_train)
x_val = np.array(x_val)
x_test  = np.array(x_test)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test  = np.array(y_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test  = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_val = np.reshape(y_val, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((3746, 20, 1), (3746, 1), (751, 20, 1), (751, 1), (501, 20, 1), (501, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model2 = Sequential()
model2.add(LSTM(units = 128, return_sequences = True, input_shape = (x_train.shape[1],1)))
model2.add(Dropout(0.2))
model2.add(LSTM(units = 64, return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(units = 50))
model2.add(Dropout(0.2))
model2.add(Dense(units=128,activation='relu'))
model2.add(Dense(units=1,activation='linear'))

'''
model = Sequential()
model.add(InputLayer((x_train.shape[1],1)))
model.add(LSTM(64))
model.add(Dense(8,'relu'))
model.add(Dense(1,'linear'))
'''
model2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_35 (LSTM)                  │ (None, 20, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_36 (LSTM)                  │ (None, 20, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 20, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_37 (LSTM)                  │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │         6,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,625 (568.85 KB)
#  Trainable params: 145,625 (568.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model/lstm2.keras',save_best_only = True)
model2.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate = 0.00001),metrics = [RootMeanSquaredError()])

# %%
# %%time
model2.fit(x_train,y_train,validation_data=(x_val,y_val), epochs= 50,callbacks=[cp2])
# Out:
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.0993 - root_mean_squared_error: 0.3150 - val_loss: 0.2476 - val_root_mean_squared_error: 0.4976
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - loss: 0.0798 - root_mean_squared_error: 0.2824 - val_loss: 0.1692 - val_root_mean_squared_error: 0.4113
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 0.0464 - root_mean_squared_error: 0.2146 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 0.0078 - root_mean_squared_error: 0.0875 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0345
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 7.4077e-04 - val_root_mean_squared_error: 0.0272
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 7.1063e-04 - val_root_mean_squared_error: 0.0267
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 3.5872e-04 - val_root_mean_squared_error: 0.0189
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0022 - root_mean_squared_error: 0.0467 - val_loss: 3.1553e-04 - val_root_mean_squared_error: 0.0178
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 0.0020 - root_mean_squared_error: 0.0444 - val_loss: 3.7198e-04 - val_root_mean_squared_error: 0.0193
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 2.3944e-04 - val_root_mean_squared_error: 0.0155
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 0.0017 - root_mean_squared_error: 0.0408 - val_loss: 2.3472e-04 - val_root_mean_squared_error: 0.0153
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0015 - root_mean_squared_error: 0.0392 - val_loss: 2.3212e-04 - val_root_mean_squared_error: 0.0152
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 2.4950e-04 - val_root_mean_squared_error: 0.0158
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 2.4021e-04 - val_root_mean_squared_error: 0.0155
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 2.4634e-04 - val_root_mean_squared_error: 0.0157
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 2.4400e-04 - val_root_mean_squared_error: 0.0156
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 2.6032e-04 - val_root_mean_squared_error: 0.0161
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 2.4156e-04 - val_root_mean_squared_error: 0.0155
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 2.8887e-04 - val_root_mean_squared_error: 0.0170
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 2.4150e-04 - val_root_mean_squared_error: 0.0155
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 9.4775e-04 - root_mean_squared_error: 0.0307 - val_loss: 3.6105e-04 - val_root_mean_squared_error: 0.0190
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 9.5789e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.0981e-04 - val_root_mean_squared_error: 0.0202
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 5.0704e-04 - val_root_mean_squared_error: 0.0225
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 9.9007e-04 - root_mean_squared_error: 0.0315 - val_loss: 3.1830e-04 - val_root_mean_squared_error: 0.0178
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - loss: 9.5386e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.2055e-04 - val_root_mean_squared_error: 0.0228
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 8.9914e-04 - root_mean_squared_error: 0.0300 - val_loss: 7.2203e-04 - val_root_mean_squared_error: 0.0269
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 9.0371e-04 - root_mean_squared_error: 0.0300 - val_loss: 5.3826e-04 - val_root_mean_squared_error: 0.0232
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 8.6518e-04 - root_mean_squared_error: 0.0294 - val_loss: 5.7570e-04 - val_root_mean_squared_error: 0.0240
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 7.9591e-04 - root_mean_squared_error: 0.0282 - val_loss: 5.6033e-04 - val_root_mean_squared_error: 0.0237
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 8.4729e-04 - root_mean_squared_error: 0.0291 - val_loss: 8.1763e-04 - val_root_mean_squared_error: 0.0286
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 7.7946e-04 - root_mean_squared_error: 0.0279 - val_loss: 7.4804e-04 - val_root_mean_squared_error: 0.0274
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 7.5500e-04 - root_mean_squared_error: 0.0275 - val_loss: 8.9427e-04 - val_root_mean_squared_error: 0.0299
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 7.4431e-04 - root_mean_squared_error: 0.0273 - val_loss: 9.1366e-04 - val_root_mean_squared_error: 0.0302
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 7.7296e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 7.7394e-04 - root_mean_squared_error: 0.0278 - val_loss: 8.4486e-04 - val_root_mean_squared_error: 0.0291
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 6.7653e-04 - root_mean_squared_error: 0.0260 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0399
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 6.8164e-04 - root_mean_squared_error: 0.0261 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 6.5989e-04 - root_mean_squared_error: 0.0257 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0386
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 6.6644e-04 - root_mean_squared_error: 0.0258 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.4128e-04 - root_mean_squared_error: 0.0253 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0429
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 6.4486e-04 - root_mean_squared_error: 0.0254 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0472
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 5.9356e-04 - root_mean_squared_error: 0.0244 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 5.5087e-04 - root_mean_squared_error: 0.0235 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0496
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 5.6494e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0481
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 6.0246e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0500
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 5.5814e-04 - root_mean_squared_error: 0.0236 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0502
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 5.7314e-04 - root_mean_squared_error: 0.0239 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0498
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 5.9409e-04 - root_mean_squared_error: 0.0244 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0563
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 5.6129e-04 - root_mean_squared_error: 0.0237 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0602
# CPU times: user 8min, sys: 16.6 s, total: 8min 16s
# Wall time: 7min 38s

# %%
from tensorflow.keras.models import load_model
model2 = load_model('model/lstm2.keras')

# Evaluate the model
result2 = model2.evaluate(x_test, y_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.3504e-04 - root_mean_squared_error: 0.0153

# %%
# Make predictions
# %%time
y_pred2 = model2.predict(x_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# CPU times: user 1.66 s, sys: 76.5 ms, total: 1.73 s
# Wall time: 1.78 s

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE = mean_absolute_percentage_error(y_test, y_pred2)
Accuracy = 1 - MAPE
print("Test Loss:", result[0])
print("Test RMSE:", result[1])
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0001768276997609064
# Test RMSE: 0.01329765748232603
# Test MAPE: 0.018995920476462144
# Test Accuracy: 0.9810040795235379
# Test R2 Score: 0.9808972165198658

# %%
y_val_pred = model2.predict(x_val)
y_val_true = scaler.inverse_transform(y_val)
y_val_pred = scaler.inverse_transform(y_val_pred)
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred2)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
plt.figure(figsize=(18, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'green'
plt.rc('axes',edgecolor='white')
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df.index[train_size:train_size+val_size], y_val_true, color='blue', lw=2) # Valid True
plt.plot(df.index[train_size:train_size+val_size], y_val_pred, color='red', lw=2) # Valid Pred
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_true, color='yellow', lw=2) # Test True
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_pred, color='orange', lw=2)# Test Pred
plt.title('Model Performance on Gold Price Prediction Using LSTM(Feature: Price Only)', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Valid Data', 'Predicted Valid Data','Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # **Price + Economy Indexes**

# %% [markdown]
# After Visualizing the correlation and relationship between close and other features, we assume that all of Price features have a near 1 relationship with Close price except Volume. Moreover, **SMA10 and SMA20** have a direct variation except RSI since it's called a momentum indicator. For relationship between Close Price and Economy indexes, after visualizing in pairplot and correlation table, PPI, GDP, and CPI have high correlation and a direct variation with Close price. However, CIV has an inverse variation with Close Price.

# %%
df.head()
# Out:
#          Date       Close        High         Low        Open  Volume  \
# 0  2005-03-28  425.899994  425.899994  425.899994  425.899994       0
# 1  2005-03-29  426.000000  426.000000  426.000000  426.000000       0
# 2  2005-03-31  428.700012  428.700012  428.700012  428.700012    3051
# 3  2005-04-01  425.899994  428.500000  424.500000  428.299988     552
# 4  2005-04-04  423.899994  426.299988  422.700012  426.000000     486
#
#          RSI       SMA10       SMA20  CPIAUCSL  CIVPART        GDP  \
# 0  33.386323  434.190002  435.730000     193.1     65.9  12767.286
# 1  33.629056  432.680002  435.205000     193.1     65.9  12767.286
# 2  39.987248  431.460004  434.995001     193.1     65.9  12767.286
# 3  36.122564  429.680002  434.650002     193.7     66.1  12922.656
# 4  33.622901  428.200000  434.350002     193.7     66.1  12922.656
#
#    GEPUCURRENT  PPIACO  UNRATE       CLI  GDP_Reference
# 0    54.055710   153.7     5.2  100.3446       100.4980
# 1    54.055710   153.7     5.2  100.3446       100.4980
# 2    54.055710   153.7     5.2  100.3446       100.4980
# 3    68.682759   155.0     5.2  100.2931       100.5254
# 4    68.682759   155.0     5.2  100.2931       100.5254

# %%
train_data = df.Close[:train_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

val_data = df.Close[train_size:train_size+val_size]
val_data = scaler.transform(val_data.values.reshape(-1,1))

test_data = df.Close[train_size+val_size:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
train_data_high = df.High[:train_size]
train_data_high = scaler.transform(train_data_high.values.reshape(-1,1))

val_data_high = df.High[train_size:train_size+val_size]
val_data_high = scaler.transform(val_data_high.values.reshape(-1,1))

test_data_high = df.High[train_size+val_size:]
test_data_high = scaler.transform(test_data_high.values.reshape(-1,1))

# %%
train_data_1 = df.PPIACO[:train_size]
train_data_1 = scaler.transform(train_data_1.values.reshape(-1,1))

val_data_1 = df.PPIACO[train_size:train_size+val_size]
val_data_1 = scaler.transform(val_data_1.values.reshape(-1,1))

test_data_1 = df.PPIACO[train_size+val_size:]
test_data_1 = scaler.transform(test_data_1.values.reshape(-1,1))

# %%
train_data_2 = df.GDP[:train_size]
train_data_2 = scaler.transform(train_data_2.values.reshape(-1,1))

val_data_2 = df.GDP[train_size:train_size+val_size]
val_data_2 = scaler.transform(val_data_2.values.reshape(-1,1))

test_data_2 = df.GDP[train_size+val_size:]
test_data_2 = scaler.transform(test_data_2.values.reshape(-1,1))

# %%
window=10
x_train=[]
y_train = []
for i in range(train_size-window) :
  temp = train_data[i:i+window]
  temp = np.append(temp, train_data_high[i:i+window])
  temp = np.append(temp, train_data_2[i])
  x_train.append(temp)
  y_train.append(train_data[i+window])

# %%
x_val=[]
y_val = []
for i in range(window) :
  temp = train_data[i+train_size-(2*window):i+train_size-window]
  temp = np.append(temp, train_data_high[i+train_size-window-window:i+train_size-window])
  temp = np.append(temp, train_data_2[i+train_size-window-window:i+train_size-window])
  x_val.append(temp)
  y_val.append(train_data[i+train_size-window])
for i in range(val_size-window) :
  temp = val_data[i:i+window]
  temp = np.append(temp, val_data_high[i:i+window])
  temp = np.append(temp, val_data_2[i:i+window])
  x_val.append(temp)
  y_val.append(val_data[i+window])

# %%
x_test=[]
y_test = []
for i in range(window) :
  temp = val_data[i-window-window+len(x_val):i+len(x_val)-window]
  temp = np.append(temp, val_data_high[i+len(x_val)-window-window:i+len(x_val)-window])
  temp = np.append(temp, val_data_2[i+len(x_val)-window-window:i+len(x_val)-window])
  x_test.append(temp)
  y_test.append(val_data[i+len(x_val)-window-window])
for i in range(test_size-window) :
  temp = test_data[i:i+window]
  temp = np.append(temp, test_data_high[i:i+window])
  temp = np.append(temp, test_data_2[i:i+window])
  x_test.append(temp)
  y_test.append(test_data[i+window])

# %%
x_train = np.array(x_train)
x_val = np.array(x_val)
x_test  = np.array(x_test)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test  = np.array(y_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test  = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_val = np.reshape(y_val, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((3746, 10, 1), (3746, 1), (751, 10, 1), (751, 1), (501, 10, 1), (501, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model2 = Sequential()
model2.add(LSTM(units = 128, return_sequences = True, input_shape = (x_train.shape[1],1)))
model2.add(Dropout(0.2))
model2.add(LSTM(units = 64, return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(units = 50))
model2.add(Dropout(0.2))
model2.add(Dense(units=128,activation='relu'))
model2.add(Dense(units=1,activation='linear'))

'''
model = Sequential()
model.add(InputLayer((x_train.shape[1],1)))
model.add(LSTM(64))
model.add(Dense(8,'relu'))
model.add(Dense(1,'linear'))
'''
model2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 10, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 10, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 50)             │        23,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         6,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,625 (568.85 KB)
#  Trainable params: 145,625 (568.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model/lstm2.keras',save_best_only = True)
model2.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate = 0.00001),metrics = [RootMeanSquaredError()])

# %%
# %%time
model2.fit(x_train,y_train,validation_data=(x_val,y_val), epochs= 20,callbacks=[cp2])
# Out:
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - loss: 0.1005 - root_mean_squared_error: 0.3170 - val_loss: 0.2697 - val_root_mean_squared_error: 0.5194
# Epoch 2/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862 - val_loss: 0.2093 - val_root_mean_squared_error: 0.4575
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 0.0561 - root_mean_squared_error: 0.2367 - val_loss: 0.1188 - val_root_mean_squared_error: 0.3447
# Epoch 4/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0256 - root_mean_squared_error: 0.1594 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1736
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 8/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0633
# Epoch 9/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 10/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 11/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 0.0026 - root_mean_squared_error: 0.0506 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423
# Epoch 12/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0023 - root_mean_squared_error: 0.0481 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 13/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 0.0020 - root_mean_squared_error: 0.0443 - val_loss: 7.0982e-04 - val_root_mean_squared_error: 0.0266
# Epoch 14/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0017 - root_mean_squared_error: 0.0410 - val_loss: 4.7718e-04 - val_root_mean_squared_error: 0.0218
# Epoch 15/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 3.7901e-04 - val_root_mean_squared_error: 0.0195
# Epoch 16/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 3.4409e-04 - val_root_mean_squared_error: 0.0185
# Epoch 17/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0014 - root_mean_squared_error: 0.0367 - val_loss: 3.5985e-04 - val_root_mean_squared_error: 0.0190
# Epoch 18/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 4.0972e-04 - val_root_mean_squared_error: 0.0202
# Epoch 19/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 3.9704e-04 - val_root_mean_squared_error: 0.0199
# Epoch 20/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 4.1372e-04 - val_root_mean_squared_error: 0.0203
# CPU times: user 1min 58s, sys: 4.36 s, total: 2min 2s
# Wall time: 1min 40s

# %%
from tensorflow.keras.models import load_model
model2 = load_model('model/lstm2.keras')

# Evaluate the model
result2 = model2.evaluate(x_test, y_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.1839e-04 - root_mean_squared_error: 0.0267

# %%
# Make predictions
# %%time
y_pred2 = model2.predict(x_test)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# CPU times: user 1.25 s, sys: 66.2 ms, total: 1.32 s
# Wall time: 1.23 s

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE = mean_absolute_percentage_error(y_test, y_pred2)
Accuracy = 1 - MAPE
print("Test Loss:", result[0])
print("Test RMSE:", result[1])
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0020416511688381433
# Test RMSE: 0.04518463462591171
# Test MAPE: 0.044306634228348636
# Test Accuracy: 0.9556933657716513
# Test R2 Score: 0.8649321560477582

# %%
y_val_pred = model2.predict(x_val)
y_val_true = scaler.inverse_transform(y_val)
y_val_pred = scaler.inverse_transform(y_val_pred)
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred2)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
plt.figure(figsize=(18, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'green'
plt.rc('axes',edgecolor='white')
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df.index[train_size:train_size+val_size], y_val_true, color='blue', lw=2) # Valid True
plt.plot(df.index[train_size:train_size+val_size], y_val_pred, color='red', lw=2) # Valid Pred
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_true, color='yellow', lw=2) # Test True
plt.plot(df.index[train_size+val_size-window:train_size+val_size+test_size-window], y_test_pred, color='orange', lw=2)# Test Pred
plt.title('Model Performance on Gold Price Prediction Using LSTM(Feature: Price Only)', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Valid Data', 'Predicted Valid Data','Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # **Price + Indicators + Economy Indexes**

# %%
df.head()
# Out:
#    Unnamed: 0        Date       Close        High         Low        Open  \
# 0           0  2005-03-28  425.899994  425.899994  425.899994  425.899994
# 1           1  2005-03-29  426.000000  426.000000  426.000000  426.000000
# 2           2  2005-03-31  428.700012  428.700012  428.700012  428.700012
# 3           3  2005-04-01  425.899994  428.500000  424.500000  428.299988
# 4           4  2005-04-04  423.899994  426.299988  422.700012  426.000000
#
#    Volume        RSI       SMA10       SMA20  CPIAUCSL  CIVPART        GDP  \
# 0       0  33.386323  434.190002  435.730000     193.1     65.9  12767.286
# 1       0  33.629056  432.680002  435.205000     193.1     65.9  12767.286
# 2    3051  39.987248  431.460004  434.995001     193.1     65.9  12767.286
# 3     552  36.122564  429.680002  434.650002     193.7     66.1  12922.656
# 4     486  33.622901  428.200000  434.350002     193.7     66.1  12922.656
#
#    GEPUCURRENT  PPIACO  UNRATE       CLI  GDP_Reference
# 0    54.055710   153.7     5.2  100.3446       100.4980
# 1    54.055710   153.7     5.2  100.3446       100.4980
# 2    54.055710   153.7     5.2  100.3446       100.4980
# 3    68.682759   155.0     5.2  100.2931       100.5254
# 4    68.682759   155.0     5.2  100.2931       100.5254
